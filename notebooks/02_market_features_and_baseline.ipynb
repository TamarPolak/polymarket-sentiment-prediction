# %% [markdown]
# <a href="https://colab.research.google.com/github/TamarPolak/polymarket-sentiment-prediction/blob/main/notebooks/02_market_features_and_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/TamarPolak/polymarket-sentiment-prediction.git
# Out:
# Cloning into 'polymarket-sentiment-prediction'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 37 (delta 9), reused 26 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (37/37), 9.80 KiB | 1.40 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %cd polymarket-sentiment-prediction
# Out:
# /content/polymarket-sentiment-prediction

# %%
# !pip install pandas requests scikit-learn matplotlib

# %%
# !python src/collect_price_history.py
# Out:
# Fetching price history for Benjamin Netanyahu...
# Found 169 price points for Benjamin Netanyahu
# Fetching price history for Naftali Bennett...
# Found 169 price points for Naftali Bennett
#
# Saved price history to data/raw/polymarket_price_history.csv
#             candidate  ...  price
# 0  Benjamin Netanyahu  ...  0.380
# 1  Benjamin Netanyahu  ...  0.380
# 2  Benjamin Netanyahu  ...  0.380
# 3  Benjamin Netanyahu  ...  0.380
# 4  Benjamin Netanyahu  ...  0.365
#
# [5 rows x 4 columns]

# %%
# !python src/train_binary_model.py
# Out:
# First rows of binary ML dataset:
# candidate           timestamp  ...  target
# 2         2026-05-22 14:00:00  ...  Stable
# 3         2026-05-22 15:00:00  ...    Move
# 4         2026-05-22 16:00:00  ...  Stable
# 5         2026-05-22 17:00:00  ...  Stable
# 6         2026-05-22 18:00:00  ...  Stable
#
# [5 rows x 12 columns]
# ========== DATA CHECK ==========
#
# Dataset size: 165
#
# Target distribution:
# target
# Stable    137
# Move       28
# Name: count, dtype: int64
#
# Target distribution percentage:
# target
# Stable    0.830303
# Move      0.169697
# Name: proportion, dtype: float64
#
# Train size: 132
# Test size: 33
#
# ========== DUMMY BASELINE RESULTS ==========
#
# DUMMY BASELINE Accuracy: 0.8787878787878788
# DUMMY BASELINE F1 macro: 0.46774193548387094
#
# DUMMY BASELINE classification report:
#               precision    recall  f1-score   support
#
#         Move       0.00      0.00      0.00         4
#       Stable       0.88      1.00      0.94        29
#
# ...
